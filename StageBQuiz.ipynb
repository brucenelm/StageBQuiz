# %% [markdown]
# <a href="https://colab.research.google.com/github/brucenelm/StageBQuiz/blob/master/StageBQuiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
sns.heatmap(df.corr())

# %%
df.corr()
# Out:
#              Appliances    lights        T1  ...  Tdewpoint       rv1       rv2
# Appliances     1.000000  0.197278  0.055447  ...   0.015353 -0.011145 -0.011145
# lights         0.197278  1.000000 -0.023528  ...  -0.036322  0.000521  0.000521
# T1             0.055447 -0.023528  1.000000  ...   0.571309 -0.006203 -0.006203
# RH_1           0.086031  0.106968  0.164006  ...   0.639106 -0.000699 -0.000699
# T2             0.120073 -0.005622  0.836834  ...   0.582602 -0.011087 -0.011087
# RH_2          -0.060465  0.050985 -0.002509  ...   0.499152  0.006275  0.006275
# T3             0.085060 -0.097393  0.892402  ...   0.645886 -0.005194 -0.005194
# RH_3           0.036292  0.131161 -0.028550  ...   0.414387 -0.000477 -0.000477
# T4             0.040281 -0.008859  0.877001  ...   0.519471 -0.001815 -0.001815
# RH_4           0.016965  0.114936  0.097861  ...   0.616509 -0.001787 -0.001787
# T5             0.019760 -0.078745  0.885247  ...   0.588362 -0.005490 -0.005490
# ...

# %% [markdown]
# ### **Mean Absolute Error **

# %%
#Normalizing data to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
drop_df = df.drop(columns=['date', 'lights'])
normalised_df = pd.DataFrame(scaler.fit_transform(drop_df),columns = drop_df.columns)
features_df = normalised_df.drop(columns=['Appliances'])
Appliances_target = normalised_df['Appliances']

# %%
drop_df.head()
# Out:
#    Appliances     T1       RH_1  ...  Tdewpoint        rv1        rv2
# 0          60  19.89  47.596667  ...        5.3  13.275433  13.275433
# 1          60  19.89  46.693333  ...        5.2  18.606195  18.606195
# 2          50  19.89  46.300000  ...        5.1  28.642668  28.642668
# 3          50  19.89  46.066667  ...        5.0  45.410389  45.410389
# 4          60  19.89  46.333333  ...        4.9  10.084097  10.084097
#
# [5 rows x 27 columns]

# %%
features_df.head()
# Out:
#         T1      RH_1        T2  ...  Tdewpoint       rv1       rv2
# 0  0.32735  0.566187  0.225345  ...   0.538462  0.265449  0.265449
# 1  0.32735  0.541326  0.225345  ...   0.533937  0.372083  0.372083
# 2  0.32735  0.530502  0.225345  ...   0.529412  0.572848  0.572848
# 3  0.32735  0.524080  0.225345  ...   0.524887  0.908261  0.908261
# 4  0.32735  0.531419  0.225345  ...   0.520362  0.201611  0.201611
#
# [5 rows x 26 columns]

# %%
Appliances_target.head()
# Out:
# 0    0.046729
# 1    0.046729
# 2    0.037383
# 3    0.037383
# 4    0.046729
# Name: Appliances, dtype: float64

# %%
#Splitting the Dataset between training and testing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train,X_test,y_train,y_test = train_test_split(features_df,Appliances_target,test_size = 0.3,random_state=42)

linear_model = LinearRegression()
#Fitting the model to the training dataset
linear_model.fit(X_train,y_train)
#Obtaining the Predictions
predicted_values = linear_model.predict(X_test)

# %%
linear_model.intercept_
# Out:
# 0.1529029588225302

# %%
linear_model.coef_
# Out:
# array([-0.00328105,  0.5535466 , -0.23617792, -0.45669795,  0.29062714,
#         0.09604827,  0.028981  ,  0.02638578, -0.01565684,  0.01600579,
#         0.23642491,  0.03804865,  0.01031878, -0.04461364,  0.10199505,
#        -0.15759548, -0.18994077, -0.03980032, -0.32185967,  0.00683933,
#        -0.07767065,  0.02918313,  0.01230661,  0.11775773,  0.0007701 ,
#         0.0007701 ])

# %% [markdown]
# ## **Calculating how good a Model is**

# %%
#Mean Absolute Error (MAE)
#The Smaller the MAE the better
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,predicted_values)
round(mae,3)
# Out:
# 0.05

# %%
#Residual Sum of Squares (RSS)
#sum of squared residuals (SSR)
#The lower the RSS, the better the model’s estimations
import numpy as np
rss = np.sum(np.square(y_test-predicted_values))
round(rss,2)
# Out:
# 45.35

# %%
#Root Mean Square Error (RMSE)
#The Lower the better
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_absolute_error(y_test,predicted_values))
round(rmse,2)
# Out:
# 0.22

# %%
#R-Sqaured
#coefficient of determination
#The Higher the value the better the Model(Not necesarily true)
from sklearn.metrics import r2_score
r2_score = r2_score(y_test,predicted_values)
round(r2_score,2)
# Out:
# 0.15

# %% [markdown]
# ## **Penalization Methods**

# %%
#Ridge Regression
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha = 0.5)
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#Lasso Regression
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predicted_values_lasso = lasso_reg.predict(X_test)

# %%
#Root Mean Square Error (RMSE)
#The Lower the better
from sklearn.metrics import mean_squared_error
rmse1 = np.sqrt(mean_absolute_error(y_test,predicted_values_lasso))
round(rmse1,2)
# Out:
# 0.29

# %%
#Comparing The Effects of the Regressions
def get_weights_df(model, feat, col_name):
  #This function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features',col_name]
  weights_df[col_name].round(3)
  return weights_df

# %%
linear_model_weights = get_weights_df(linear_model,X_train,'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg,X_train,'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg,X_train,'Lasso_Weight')

# %%
final_weights = pd.merge(linear_model_weights,ridge_weights_df, on = 'Features')
final_weights = pd.merge(final_weights,lasso_weights_df, on = 'Features')

# %%
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0          RH_2            -0.456698     -0.401134     -0.000000
# 1         T_out            -0.321860     -0.250765      0.000000
# 2            T2            -0.236178     -0.193880      0.000000
# 3            T9            -0.189941     -0.188584     -0.000000
# 4          RH_8            -0.157595     -0.156596     -0.000110
# 5        RH_out            -0.077671     -0.050541     -0.049557
# 6          RH_7            -0.044614     -0.046291     -0.000000
# 7          RH_9            -0.039800     -0.041701     -0.000000
# 8            T5            -0.015657     -0.020727     -0.000000
# 9            T1            -0.003281     -0.021549      0.000000
# 10          rv1             0.000770      0.000743     -0.000000
# 11          rv2             0.000770      0.000743     -0.000000
# 12  Press_mm_hg             0.006839      0.006516     -0.000000
# ...

# %%
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
import numpy as np

# %%
T2_x = normalised_df['T2']
T6_y = normalised_df['T6']

# %%
X_train,X_test,y_train,y_test = train_test_split(T2_x,T6_y,test_size = 0.3,random_state=42)
X_train.reshape(1,size_train), ... Y_test.reshape(1, size_test)
lm = LinearRegression()
#Fitting the model to the training dataset
lm.fit(X_train.reshape(1,size_train),y_test.reshape(1, size_test))
#Obtaining the Predictions
predicted_values = linear_model.predict(X_test)
# Out:
#   File "<ipython-input-117-a9f4ffd44eb5>", line 2
#     X_train.reshape(1,size_train), ... Y_test.reshape(1, size_test)
#                                             ^
# SyntaxError: invalid syntax

# %%
#Ridge Regression
from sklearn.linear_model import Ridge
ridge_reg1 = Ridge(alpha = 0.4)
ridge_reg1.fit(X_train,y_train)
pred_val = ridge_reg1.predict(X_test)

# %%
#Root Mean Square Error (RMSE)
#The Lower the better
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_absolute_error(y_test,pred_val))
round(rmse,2)
# Out:
# 0.29

# %%
lasso_weights_df
# Out:
#        Features  Lasso_Weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880
